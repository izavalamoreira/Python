# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sqlite3

# %%
con_sqlite = sqlite3.connect("database.sqlite")

# %%
sql_query = "SELECT name FROM sqlite_master WHERE type = 'table'"

# %%
df = pd.read_sql_query(sql_query, con_sqlite)

# %%
print(df)
# Out:
#                 name
# 0    sqlite_sequence
# 1  Player_Attributes
# 2             Player
# 3              Match
# 4             League
# 5            Country
# 6               Team
# 7    Team_Attributes

# %%
Equipos = pd.read_sql_query("SELECT * FROM Team_Attributes ", con_sqlite)
Equipos
# Out:
#         id  team_fifa_api_id  team_api_id                 date  \
# 0        1               434         9930  2010-02-22 00:00:00
# 1        2               434         9930  2014-09-19 00:00:00
# 2        3               434         9930  2015-09-10 00:00:00
# 3        4                77         8485  2010-02-22 00:00:00
# 4        5                77         8485  2011-02-22 00:00:00
# ...    ...               ...          ...                  ...
# 1453  1454             15005        10000  2011-02-22 00:00:00
# 1454  1455             15005        10000  2012-02-22 00:00:00
# 1455  1456             15005        10000  2013-09-20 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# ...

# %%
Equipos.head()
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
# 2   3               434         9930  2015-09-10 00:00:00                47
# 3   4                77         8485  2010-02-22 00:00:00                70
# 4   5                77         8485  2011-02-22 00:00:00                47
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
# 2              Balanced                  41.0                    Normal
# 3                  Fast                   NaN                    Little
# 4              Balanced                   NaN                    Little
#
# ...

# %%
Equipos
# Out:
#         id  team_fifa_api_id  team_api_id                 date  \
# 0        1               434         9930  2010-02-22 00:00:00
# 1        2               434         9930  2014-09-19 00:00:00
# 2        3               434         9930  2015-09-10 00:00:00
# 3        4                77         8485  2010-02-22 00:00:00
# 4        5                77         8485  2011-02-22 00:00:00
# ...    ...               ...          ...                  ...
# 1453  1454             15005        10000  2011-02-22 00:00:00
# 1454  1455             15005        10000  2012-02-22 00:00:00
# 1455  1456             15005        10000  2013-09-20 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# ...

# %%
Prueba = Equipos.dropna()

# %%
#Pairplot
sns.pairplot(Prueba,hue = 'buildUpPlaySpeedClass' , size = 3 , palette = 'Set2')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
Prueba
# Out:
#         id  team_fifa_api_id  team_api_id                 date  \
# 1        2               434         9930  2014-09-19 00:00:00
# 2        3               434         9930  2015-09-10 00:00:00
# 7        8                77         8485  2014-09-19 00:00:00
# 8        9                77         8485  2015-09-10 00:00:00
# 13      14               614         8576  2014-09-19 00:00:00
# ...    ...               ...          ...                  ...
# 1449  1450               244         8394  2015-09-10 00:00:00
# 1450  1451            112512         8027  2014-09-19 00:00:00
# 1451  1452            112512         8027  2015-09-10 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 1                   52              Balanced                  48.0
# 2                   47              Balanced                  41.0
# ...

# %%
Prueba.shape
# Out:
# (489, 25)

# %%
Prueba.buildUpPlaySpeedClass.unique()
# Out:
# array(['Balanced', 'Fast', 'Slow'], dtype=object)

# %%
Prueba.buildUpPlayPassingClass.unique()
# Out:
# array(['Mixed', 'Short', 'Long'], dtype=object)

# %%
Prueba.chanceCreationShootingClass.unique()
# Out:
# array(['Normal', 'Lots', 'Little'], dtype=object)

# %%
Prueba.chanceCreationPositioningClass.unique()
# Out:
# array(['Organised', 'Free Form'], dtype=object)

# %%
Prueba.defenceAggressionClass.unique()
# Out:
# array(['Press', 'Double', 'Contain'], dtype=object)

# %%
Prueba.defenceTeamWidthClass.unique()
# Out:
# array(['Normal', 'Wide', 'Narrow'], dtype=object)

# %%
Prueba.defenceDefenderLineClass.unique()
# Out:
# array(['Cover', 'Offside Trap'], dtype=object)

# %%
Prueba.defencePressureClass.unique()
# Out:
# array(['Medium', 'High', 'Deep'], dtype=object)

# %%
sns.FacetGrid(Prueba,hue = 'defenceAggressionClass' , size = 5).map(plt.scatter,'buildUpPlaySpeed','buildUpPlayDribbling').add_legend();
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(Prueba,hue = 'buildUpPlaySpeedClass' , size = 5).map(plt.scatter,'buildUpPlaySpeed','defenceAggression').add_legend();
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
