# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sqlite3

# %%
con_sqlite = sqlite3.connect("database.sqlite")

# %%
sql_query = "SELECT name FROM sqlite_master WHERE type = 'table'"

# %%
df = pd.read_sql_query(sql_query, con_sqlite)

# %%
print(df)
# Out:
#                 name
# 0    sqlite_sequence
# 1  Player_Attributes
# 2             Player
# 3              Match
# 4             League
# 5            Country
# 6               Team
# 7    Team_Attributes

# %%
Equipos1 = pd.read_sql_query("SELECT * FROM Team as T INNER JOIN Team_Attributes as T2 ON T.team_api_id= T2.team_api_id ", con_sqlite)
Equipos1
# Out:
#          id  team_api_id  team_fifa_api_id    team_long_name team_short_name  \
# 0     49119         9930               434          FC Aarau             AAR
# 1     49119         9930               434          FC Aarau             AAR
# 2     49119         9930               434          FC Aarau             AAR
# 3     39393         8485                77          Aberdeen             ABE
# 4     39393         8485                77          Aberdeen             ABE
# ...     ...          ...               ...               ...             ...
# 1453      3        10000             15005  SV Zulte-Waregem             ZUL
# 1454      3        10000             15005  SV Zulte-Waregem             ZUL
# 1455      3        10000             15005  SV Zulte-Waregem             ZUL
# 1456      3        10000             15005  SV Zulte-Waregem             ZUL
# 1457      3        10000             15005  SV Zulte-Waregem             ZUL
#
# ...

# %%
Equipos2 = pd.read_sql_query("SELECT * FROM Team as T   ", con_sqlite)
Equipos2
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
Equipos3 = pd.read_sql_query("SELECT * FROM Team_Attributes ", con_sqlite)
Equipos3
# Out:
#         id  team_fifa_api_id  team_api_id                 date  \
# 0        1               434         9930  2010-02-22 00:00:00
# 1        2               434         9930  2014-09-19 00:00:00
# 2        3               434         9930  2015-09-10 00:00:00
# 3        4                77         8485  2010-02-22 00:00:00
# 4        5                77         8485  2011-02-22 00:00:00
# ...    ...               ...          ...                  ...
# 1453  1454             15005        10000  2011-02-22 00:00:00
# 1454  1455             15005        10000  2012-02-22 00:00:00
# 1455  1456             15005        10000  2013-09-20 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# ...

# %%
#Lo que hice fue fijarme la diferencia entre la conformacion de las dos tablas

# %%
Equipos = Equipos1.drop
Equipos
# Out:
# <bound method DataFrame.drop of          id  team_api_id  team_fifa_api_id    team_long_name team_short_name  \
# 0     49119         9930               434          FC Aarau             AAR
# 1     49119         9930               434          FC Aarau             AAR
# 2     49119         9930               434          FC Aarau             AAR
# 3     39393         8485                77          Aberdeen             ABE
# 4     39393         8485                77          Aberdeen             ABE
# ...     ...          ...               ...               ...             ...
# 1453      3        10000             15005  SV Zulte-Waregem             ZUL
# 1454      3        10000             15005  SV Zulte-Waregem             ZUL
# 1455      3        10000             15005  SV Zulte-Waregem             ZUL
# 1456      3        10000             15005  SV Zulte-Waregem             ZUL
# 1457      3        10000             15005  SV Zulte-Waregem             ZUL
#
# ...

# %%
Equipos1[['defencePressure', 'defenceAggression']].corr()#averiguar la correlacion entre dos variables
# Out:
#                    defencePressure  defenceAggression
# defencePressure           1.000000           0.422493
# defenceAggression         0.422493           1.000000

# %%
Equipos1[['chanceCreationShooting', 'buildUpPlaySpeed']].corr()#averiguar la correlacion entre dos variables
# Out:
#                         chanceCreationShooting  buildUpPlaySpeed
# chanceCreationShooting                1.000000          0.072098
# buildUpPlaySpeed                      0.072098          1.000000

# %%
Equipos1[['defencePressure', 'buildUpPlaySpeed']].corr() #averiguar la correlacion entre dos variables
# Out:
#                   defencePressure  buildUpPlaySpeed
# defencePressure          1.000000          0.046397
# buildUpPlaySpeed         0.046397          1.000000

# %%
sns.scatterplot(x=Equipos1['defencePressure'],y=Equipos1['defenceAggression'])#relacion entre defensa precisa y defensa agresiva
# Out:
# <AxesSubplot:xlabel='defencePressure', ylabel='defenceAggression'>

# %%
sns.jointplot(x=Equipos1['chanceCreationShooting'],y=Equipos1['buildUpPlaySpeed'])#relacion entre juego rapido y creacion de situaciones de gol

# %%
'defencePressure', 'buildUpPlaySpeed'
# Out:
# ('defencePressure', 'buildUpPlaySpeed')

# %%
#relacion entre juego rapido y una defensa rapida

# %%
sns.jointplot(Equipos1['chanceCreationShooting'],Equipos1['buildUpPlaySpeed'], kind='hex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
